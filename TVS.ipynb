# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from pathlib import Path

# %%
team_stats_path = "teamstats2012-2021.csv"

# %%
team_stats=pd.read_csv(team_stats_path)

# %%
df1=team_stats
df1.head(5)
# Out:
#      gameId      team  year round    playerId      displayName  gameNumber  \
# 0  2021R104  Adelaide  2021    R1  2021661124       Berry, Sam           1
# 1  2021R104  Adelaide  2021    R1  2012662083      Brown, Luke         168
# 2  2021R104  Adelaide  2021    R1  2020665315    Butts, Jordon           3
# 3  2021R104  Adelaide  2021    R1  2018689604      Doedee, Tom          31
# 4  2021R104  Adelaide  2021    R1  2018703883  Frampton, Billy           9
#
#    Disposals  Kicks  Marks  ...  Brownlow Votes  Contested Possessions  \
# 0          8      6      1  ...               0                      4
# 1          5      2      0  ...               0                      2
# 2         10      5      3  ...               0                      5
# 3         13      9      4  ...               0                      8
# 4         14     10      8  ...               0                      5
#
#    Uncontested Possessions  Contested Marks  Marks Inside 50  One Percenters  \
# 0                        5                0                0               0
# 1                        3                0                0               0
# 2                        5                1                0               8
# 3                        6                0                0               7
# 4                        9                3                4               2
#
#    Bounces  Goal Assists  % Played  Subs
# 0        0             1        80     -
# 1        0             0        23   Off
# 2        0             0        93     -
# 3        0             0        84     -
# 4        0             0        90     -
#
# [5 rows x 31 columns]

# %%
df2=df1.groupby(['team'])['Rebounds','Inside 50s','Clearances','Contested Possessions'].sum()
# Out:
# C:\Users\MOHAMMED\AppData\Local\Temp\ipykernel_13016\2270001918.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2=df1.groupby(['team'])['Rebounds','Inside 50s','Clearances','Contested Possessions'].sum()

# %%
df2
# Out:
#                         Rebounds  Inside 50s  Clearances  \
# team
# Adelaide                    8023       11769        8407
# Brisbane Lions              8135       10862        8280
# Carlton                     7693       10496        7989
# Collingwood                 7790       11621        8103
# Essendon                    7966       11141        7759
# Fremantle                   7736       10731        8232
# Geelong                     7851       12448        8586
# Gold Coast                  8166       10050        7824
# Greater Western Sydney      8715       11057        8751
# Hawthorn                    7567       12274        8547
# Melbourne                   7769       10946        7952
# North Melbourne             7937       11246        8102
# Port Adelaide               7642       11987        8693
# Richmond                    7945       12082        7994
# St Kilda                    7614       10768        7590
# Sydney                      8991       12236        8747
# West Coast                  7723       11545        8616
# Western Bulldogs            7587       11765        8529
#
#                         Contested Possessions
# team
# Adelaide                                32520
# Brisbane Lions                          29723
# Carlton                                 29460
# Collingwood                             32026
# Essendon                                29746
# Fremantle                               31166
# Geelong                                 33411
# Gold Coast                              29332
# Greater Western Sydney                  31276
# Hawthorn                                31653
# Melbourne                               31196
# North Melbourne                         30606
# Port Adelaide                           32168
# Richmond                                31529
# St Kilda                                28825
# Sydney                                  34055
# West Coast                              31504
# Western Bulldogs                        31998

# %%
df3 = df2.sum(axis = 1)

# %%
df4=pd.DataFrame(df3)

# %%
df4.columns=['TVS']

# %%
TVS=df4.sort_values(['TVS'],ascending=False)

# %%
TVS
# Out:
#                           TVS
# team
# Sydney                  64029
# Geelong                 62296
# Adelaide                60719
# Port Adelaide           60490
# Hawthorn                60041
# Western Bulldogs        59879
# Greater Western Sydney  59799
# Richmond                59550
# Collingwood             59540
# West Coast              59388
# North Melbourne         57891
# Fremantle               57865
# Melbourne               57863
# Brisbane Lions          57000
# Essendon                56612
# Carlton                 55638
# Gold Coast              55372
# St Kilda                54797

# %%
filepath = Path('TVS.csv')
TVS.to_csv(filepath)
